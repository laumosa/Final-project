# %%
import h2o
from h2o.automl import H2OAutoML
import pandas as pd

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) Client VM (build 25.371-b11, mixed mode, sharing)
#   Starting server from C:\Users\Laura\miniconda3\envs\h20\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\Laura\AppData\Local\Temp\tmpr7sj1f3w
#   JVM stdout: C:\Users\Laura\AppData\Local\Temp\tmpr7sj1f3w\h2o_Laura_started_from_python.out
#   JVM stderr: C:\Users\Laura\AppData\Local\Temp\tmpr7sj1f3w\h2o_Laura_started_from_python.err
# C:\Users\Laura\miniconda3\envs\h20\lib\site-packages\h2o\backend\server.py:386: UserWarning:   You have a 32-bit version of Java. H2O works best with 64-bit Java.
#   Please download the latest 64-bit Java SE JDK from Oracle.
#
#   warn("  You have a 32-bit version of Java. H2O works best with 64-bit Java.\n"
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# ...

# %%
saved_model = h2o.load_model('StackedEnsemble_AllModels_1_AutoML_1_20230606_144532')

# %%
saved_model
# Out:
# Model Details
# ...
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_AllModels_1_AutoML_1_20230606_144532
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       16/20
# # GBM base models (used / total)           5/7
# # XGBoost base models (used / total)       6/6
# # GLM base models (used / total)           1/1
# # DeepLearning base models (used / total)  3/4
# # DRF base models (used / total)           1/2
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.06493158462818731
# ...
